# %% [markdown]
# <a href="https://colab.research.google.com/github/luv-vik/python-learning/blob/master/Python_Practice_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Setup
# ---

# %% [markdown]
# # Variables

# %% [markdown]
# # Strings

# %% [markdown]
# # Numbers

# %% [markdown]
# # Lists

# %% [markdown]
# # Tuples

# %% [markdown]
# # Dictionaries

# %% [markdown]
# # Sets

# %% [markdown]
# # Conditions

# %% [markdown]
# # Loops

# %% [markdown]
# # Functions

# %% [markdown]
# # List Comprehensions

# %% [markdown]
# # Error Handling

# %% [markdown]
# # File Handling

# %% [markdown]
# # OOP

# %% [markdown]
# # Mini Challenges

# %% [markdown]
# # AI Preparation

# %%
print("Hello world")
# Out:
# Hello world
